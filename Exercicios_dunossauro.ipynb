# %% [markdown]
# Listas de exercicios do site do [Dunossauro](https://exercicios.dunossauro.com/)
#
# Listas de exercícios:
#
# 1. Estrutura sequencial
# 2. Estrutura de decisão
# 3. Estrutura de repetição
# 4. Exercícios sobre listas
# 5. Exercícios sobre funções
# 6. Exercícios sobre strings
# 7. Exercícios sobre manipulação de arquivos
# 8. Exercícios sobre classes
# 9. Lista de projetos
# 10. Lista de dados

# %% [markdown]
# #### Exercício 01
# Faça um programa que mostre a mensagem ```Alo mundo``` na tela:

# %%
print("Alo Mundo")
# Out:
# Alo Mundo

# %% [markdown]
# #### Exercício 02
# Faça um programa que peça um número e então mostre a mensagem ```O número informado foi [número]```:

# %%
numero = input("Digite um numero: ")

print(f"O numero digitado foi: {numero}")
# Out:
# O numero digitado foi: 10

# %% [markdown]
# #### Exercício 03
# Faça um programa que peça dois números e imprima a soma:

# %%
numero1 = float(input("Digite um numero: "))
numero2 = float(input("Digite outro numero: "))

soma = numero1 + numero2
print(f"A soma dos numeros é: {soma}")
print(f"A soma dos numeros é: {numero1 + numero2}")
# Out:
# A soma dos numeros é: 12.0
# A soma dos numeros é: 12.0

# %% [markdown]
# #### Exercício 04
# Faça um programa que peça as 4 notas bimestrais e mostre a média.

# %%
n1 = float(input("Digite um numero: "))
n2 = float(input("Digite outro numero: "))
n3 = float(input("Digite outro numero: "))
n4 = float(input("Digite outro numero: "))

media = (n1 + n2 + n3 + n4) / 4
print(f"A media dos numeros é: {media}")
# Out:
# A media dos numeros é: 5.0

# %% [markdown]
# #### Exercício 05
# Faça um programa que converta metros para centímetros:

# %%
metros = float(input("Digite um valor em metros: "))
centimetros = metros * 100

print(f"O valor em centimetros é: {centimetros}")
# Out:
# O valor em centimetros é: 1000.0

# %% [markdown]
# #### Exercício 06
# Faça um programa que peça o raio de um círculo, calcule e mostre sua área:

# %%
raio = float(input("Digite o valor do raio: "))
area = 3.14 * (raio ** 2)

print(f"A area do circulo é: {area}")
# Out:
# A area do circulo é: 314.0

# %% [markdown]
# #### Exercício 07
# Faça um programa que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

# %%
quadrado = float(input("Digite o valor do lado do quadrado: "))
area_quadrado = quadrado ** 2
print(f"A area do quadrado é: {area_quadrado}")
# Out:
# A area do quadrado é: 4.0

# %% [markdown]
# #### Exercício 08
# Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor_hora = float(input("Digite o valor da hora: "))
horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas: "))
salario = valor_hora * horas_trabalhadas
print(f"O salario é: {salario}")
# Out:
# O salario é: 2200.0

# %% [markdown]
# #### Exercício 09
# Faça um programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
#
# Formula
# ```C = 5 * ((F-32) / 9)```.

# %%
temperatura_fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))
temperatura_celsius = (temperatura_fahrenheit - 32) * 5 / 9
print(f"A temperatura em Celsius é: {temperatura_celsius}")
# Out:
# A temperatura em Celsius é: 100.0

# %% [markdown]
# #### Exercício 10
# Faça um programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
# Formula
# ```F = (C * 9/5) + 32```

# %%
temperatura_celsius = float(input("Digite a temperatura em Celsius: "))
temperatura_fahrenheit = (temperatura_celsius * 9 / 5) + 32
print(f"A temperatura em Fahrenheit é: {temperatura_fahrenheit}")
# Out:
# A temperatura em Fahrenheit é: 32.0

# %% [markdown]
# #### Exercício 11
# Faça um programa que peça 2 números inteiros e um número real. Calcule e mostre:
#
# - O produto do dobro do primeiro com metade do segundo .
# - A soma do triplo do primeiro com o terceiro.
# - O terceiro elevado ao cubo.

# %%
numero_inteiro = int(input("Digite um numero inteiro: "))
numero_inteiro2 = int(input("Digite outro numero inteiro: "))
numero_real = float(input("Digite um numero real: "))

print(f"O produto do dobro do primeiro com metade do segundo é: {(numero_inteiro * 2) * (numero_inteiro2 / 2)}")
print(f"A soma do triplo do primeiro com o terceiro é: {(numero_inteiro * 3) + numero_real}")
print(f"O terceiro elevado ao cubo é: {numero_real ** 3}")
# Out:
# O produto do dobro do primeiro com metade do segundo é: 4.0
# A soma do triplo do primeiro com o terceiro é: 8.0
# O terceiro elevado ao cubo é: 8.0

# %% [markdown]
# #### Exercício 12
# Tendo como dados de entrada um arquivo em Gigabytes, construa um algoritmo que faça a conversão para Megabytes, usando a seguinte fórmula:
#
# Formula
# ```Gigabytes * 1024```

# %%
gigabytes = float(input("Digite o valor em Gigabytes: "))
megabytes = gigabytes * 1024
print(f"O valor em megabytes é: {megabytes}")
# Out:
# O valor em megabytes é: 10240.0

# %% [markdown]
# #### Exercício 13
# Tendo como dados de entrada um arquivo em Gigabytes, construa um algoritmo que faça a conversão para Megabytes e Kilobytes, usando as seguintes fórmulas:
#
# - Para Megabytes: ```Gigabytes * 1024```
# - Para Kilobytes: ```Gigabytes * 1024 * 1024```
#
# Responda o tamanho do arquivo em Megabytes e o tamanho em Kilobytes.

# %%
gigabytes = float(input("Digite o valor em Gigabytes: "))
megabytes = gigabytes * 1024
kilobytes = megabytes * 1024
print(f"O valor em megabytes é: {megabytes}")
print(f"O valor em kilobytes é: {kilobytes}")
# Out:
# O valor em megabytes é: 10240.0
# O valor em kilobytes é: 10485760.0

# %% [markdown]
# #### Exercício 14
# João, um pescador, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso = float(input("Digite o peso em kg: "))
limite = 50
excesso = peso - limite
if excesso > 0:
    print(f"A multa a ser paga é: {excesso * 4}")
else:
    print("Não há excesso de peso. Nenhuma multa será aplicada.")
# Out:
# A multa a ser paga é: 16.0

# %% [markdown]
# #### Exercício 15
# Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:
#
# - salário bruto.
# - quanto pagou ao INSS.
# - quanto pagou ao sindicato.
# - o salário líquido.
# - calcule os descontos e o salário líquido, conforme a tabela abaixo:
#
# ```+ Salário Bruto : R$
# - IR (11%) : R$
# - INSS (8%) : R$
# - Sindicato ( 5%) : R$
# = Salário Liquido : R$
# ```
#
# > Obs.: Salário Bruto - Descontos = Salário Líquido.

# %%
valor_hora = float(input("Digite o valor da hora: "))
horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas no mês: "))

salario_bruto = valor_hora * horas_trabalhadas
imposto_renda = salario_bruto * 0.11
imposto_inss = salario_bruto * 0.08
imposto_sindicato = salario_bruto * 0.05
desconto_total = imposto_renda + imposto_inss + imposto_sindicato
salario_liquido = salario_bruto - desconto_total
print(f"Salario Bruto: R$ {salario_bruto:.2f}")
print(f"Imposto de Renda (11%): R$ {imposto_renda:.2f}")
print(f"INSS (8%): R$ {imposto_inss:.2f}")
print(f"Contribuição Sindical (5%): R$ {imposto_sindicato:.2f}")
print(f"Total de descontos: R$ {desconto_total:.2f}")
print(f"Salario Liquido: R$ {salario_liquido:.2f}")
# Out:
# Salario Bruto: R$ 4840.00
# Imposto de Renda (11%): R$ 532.40
# INSS (8%): R$ 387.20
# Contribuição Sindical (5%): R$ 242.00
# Total de descontos: R$ 1161.60
# Salario Liquido: R$ 3678.40

# %% [markdown]
# ### Exercício 16
# Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total.

# %%
area_quadrado = float(input("Digite o tamanho em metros quadrados: "))

rendimento_tinta = 18 * 3

latas_tinta = area_quadrado / rendimento_tinta

if area_quadrado % rendimento_tinta != 0:
    latas_tinta = int(latas_tinta) + 1  # Arredonda para cima se houver sobra

print(f"Quantidade de latas de tinta necessárias: {latas_tinta:.0f}")
print(f"Valor total a ser pago: R$ {latas_tinta * 80:.2f}")
# Out:
# Quantidade de latas de tinta necessárias: 2
# Valor total a ser pago: R$ 160.00
